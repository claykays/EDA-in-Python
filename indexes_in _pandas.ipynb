# %%
import pandas as pd
import  numpy as np
from matplotlib import pyplot as plt
sales_data = pd.read_excel('sampledatafoodsales.xlsx',sheet_name='FoodSales')
sales_data
# Out:
#      OrderDate Region         City  Category         Product  Quantity  \
# 0   2020-01-01   East       Boston      Bars          Carrot        33
# 1   2020-01-04   East       Boston  Crackers     Whole Wheat        87
# 2   2020-01-07   West  Los Angeles   Cookies  Chocolate Chip        58
# 3   2020-01-10   East     New York   Cookies  Chocolate Chip        82
# 4   2020-01-13   East       Boston   Cookies       Arrowroot        38
# ..         ...    ...          ...       ...             ...       ...
# 239 2021-12-18   East       Boston   Cookies       Arrowroot        34
# 240 2021-12-21   East       Boston   Cookies  Chocolate Chip       245
# 241 2021-12-24   East       Boston  Crackers     Whole Wheat        30
# 242 2021-12-27   West  Los Angeles      Bars            Bran        30
# 243 2021-12-30   West  Los Angeles   Cookies  Oatmeal Raisin        44
#
#      UnitPrice  TotalPrice
# 0         1.77       58.41
# 1         3.49      303.63
# 2         1.87      108.46
# ...

# %%
sales_data_indexed = sales_data.set_index('Category')
sales_data_indexed
# Out:
#           OrderDate Region         City         Product  Quantity  UnitPrice  \
# Category
# Bars     2020-01-01   East       Boston          Carrot        33       1.77
# Crackers 2020-01-04   East       Boston     Whole Wheat        87       3.49
# Cookies  2020-01-07   West  Los Angeles  Chocolate Chip        58       1.87
# Cookies  2020-01-10   East     New York  Chocolate Chip        82       1.87
# Cookies  2020-01-13   East       Boston       Arrowroot        38       2.18
# ...             ...    ...          ...             ...       ...        ...
# Cookies  2021-12-18   East       Boston       Arrowroot        34       2.18
# Cookies  2021-12-21   East       Boston  Chocolate Chip       245       1.87
# Crackers 2021-12-24   East       Boston     Whole Wheat        30       3.49
# Bars     2021-12-27   West  Los Angeles            Bran        30       1.87
# Cookies  2021-12-30   West  Los Angeles  Oatmeal Raisin        44       2.84
#
#           TotalPrice
# Category
# ...

# %%
sales_data_indexed.sort_index()
sort_by_cat = sales_data_indexed.sort_index(level='Category')
sort_by_cat
# Out:
#           OrderDate Region         City       Product  Quantity  UnitPrice  \
# Category
# Bars     2020-01-01   East       Boston        Carrot        33       1.77
# Bars     2020-10-07   West  Los Angeles        Carrot        40       1.77
# Bars     2021-06-03   East       Boston          Bran        27       1.87
# Bars     2020-10-01   East       Boston        Carrot        77       1.77
# Bars     2020-09-25   West    San Diego          Bran        33       1.87
# ...             ...    ...          ...           ...       ...        ...
# Snacks   2020-04-19   East       Boston  Potato Chips       134       1.68
# Snacks   2020-04-13   West    San Diego  Potato Chips        28       1.68
# Snacks   2020-04-04   West  Los Angeles  Potato Chips        68       1.68
# Snacks   2021-01-08   East       Boston      Pretzels        29       3.15
# Snacks   2021-02-22   East       Boston      Pretzels        31       3.15
#
#           TotalPrice
# Category
# Bars           58.41
# ...

# %%
sort_by_cat_slice  = sort_by_cat.loc['Bars']
sort_by_cat_slice
# Out:
#           OrderDate Region         City Product  Quantity  UnitPrice  \
# Category
# Bars     2020-01-01   East       Boston  Carrot        33       1.77
# Bars     2020-10-07   West  Los Angeles  Carrot        40       1.77
# Bars     2021-06-03   East       Boston    Bran        27       1.87
# Bars     2020-10-01   East       Boston  Carrot        77       1.77
# Bars     2020-09-25   West    San Diego    Bran        33       1.87
# ...             ...    ...          ...     ...       ...        ...
# Bars     2021-08-26   West    San Diego  Carrot        41       1.77
# Bars     2021-09-07   West  Los Angeles    Bran        50       1.87
# Bars     2020-05-04   East       Boston    Bran       105       1.87
# Bars     2021-09-19   West    San Diego  Carrot        49       1.77
# Bars     2020-06-09   West    San Diego  Carrot        42       1.77
#
#           TotalPrice
# Category
# Bars           58.41
# Bars           70.80
# Bars           50.49
# Bars          136.29
# ...

# %%
sales_data_unindexed = sales_data_indexed.reset_index(drop=False)
sales_data_unindexed
# Out:
#      Category  OrderDate Region         City         Product  Quantity  \
# 0        Bars 2020-01-01   East       Boston          Carrot        33
# 1    Crackers 2020-01-04   East       Boston     Whole Wheat        87
# 2     Cookies 2020-01-07   West  Los Angeles  Chocolate Chip        58
# 3     Cookies 2020-01-10   East     New York  Chocolate Chip        82
# 4     Cookies 2020-01-13   East       Boston       Arrowroot        38
# ..        ...        ...    ...          ...             ...       ...
# 239   Cookies 2021-12-18   East       Boston       Arrowroot        34
# 240   Cookies 2021-12-21   East       Boston  Chocolate Chip       245
# 241  Crackers 2021-12-24   East       Boston     Whole Wheat        30
# 242      Bars 2021-12-27   West  Los Angeles            Bran        30
# 243   Cookies 2021-12-30   West  Los Angeles  Oatmeal Raisin        44
#
#      UnitPrice  TotalPrice
# 0         1.77       58.41
# 1         3.49      303.63
# 2         1.87      108.46
# ...

# %%
sales_data_unindexed = sales_data_indexed.reset_index(drop=True)
sales_data_unindexed
# Out:
#      OrderDate Region         City         Product  Quantity  UnitPrice  \
# 0   2020-01-01   East       Boston          Carrot        33       1.77
# 1   2020-01-04   East       Boston     Whole Wheat        87       3.49
# 2   2020-01-07   West  Los Angeles  Chocolate Chip        58       1.87
# 3   2020-01-10   East     New York  Chocolate Chip        82       1.87
# 4   2020-01-13   East       Boston       Arrowroot        38       2.18
# ..         ...    ...          ...             ...       ...        ...
# 239 2021-12-18   East       Boston       Arrowroot        34       2.18
# 240 2021-12-21   East       Boston  Chocolate Chip       245       1.87
# 241 2021-12-24   East       Boston     Whole Wheat        30       3.49
# 242 2021-12-27   West  Los Angeles            Bran        30       1.87
# 243 2021-12-30   West  Los Angeles  Oatmeal Raisin        44       2.84
#
#      TotalPrice
# 0         58.41
# 1        303.63
# 2        108.46
# 3        153.34
# ...

# %%
# Index sales data by  city and Category
sales_data_ind = sales_data.set_index(['City','Category'])

# List of tuples: Boston, Crackers & Los Angeles, Cookies
rows_to_keep = [['Boston','Crackers'],['Los Angeles','Cookies']]

# Subset for rows to keep
print(sales_data_ind.loc[rows_to_keep])
# Out:
#                       OrderDate Region         Product  Quantity  UnitPrice  \
# City        Category
# Boston      Crackers 2020-01-04   East     Whole Wheat        87       3.49
#             Crackers 2020-01-19   East     Whole Wheat       149       3.49
#             Crackers 2020-02-06   East     Whole Wheat        28       3.49
#             Crackers 2020-03-11   East     Whole Wheat        40       3.49
#             Crackers 2020-05-31   East     Whole Wheat        33       3.49
#             Crackers 2020-06-18   East     Whole Wheat        38       3.49
#             Crackers 2020-07-12   East     Whole Wheat        42       3.49
#             Crackers 2020-08-23   East     Whole Wheat        21       3.49
#             Crackers 2020-10-04   East     Whole Wheat        38       3.49
#             Crackers 2020-10-31   East     Whole Wheat        46       3.49
#             Crackers 2020-12-15   East     Whole Wheat        41       3.49
# ...

# %%
# Calculate median plane ticket prices by Airline
airline_prices = planes.groupby("Airline")["Price"].median()

print(airline_prices)

# Convert to a dictionary
prices_dict = airline_prices.to_dict()

# Map the dictionary to the missing values
planes["Price"] = planes["Price"].fillna(planes["Airline"].map(prices_dict))

# Check for missing values
print(planes.isna().sum())
